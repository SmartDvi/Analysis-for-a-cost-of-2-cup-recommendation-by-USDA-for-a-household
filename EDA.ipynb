# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/home/moritus-peters/Documents/Analysis-for-a-cost-of-2-cup-recommendation-by-USDA-for-a-household/data/fruits.csv")

# %%
df
# Out:
#                                        Fruit    Form  RetailPrice  \
# 0                                     Apples   Fresh       1.8541
# 1                         Apples, applesauce  Canned       1.1705
# 2                     Apples, ready-to-drink   Juice       0.8699
# 3                 Apples, frozen concentrate   Juice       0.6086
# 4                                   Apricots   Fresh       3.6162
# 5                  Apricots, packed in juice  Canned       1.8645
# 6         Apricots, packed in syrup or water  Canned       2.2362
# 7                                   Apricots   Dried       7.6611
# 8                                    Bananas   Fresh       0.5971
# 9                             Berries, mixed  Frozen       4.2673
# 10                              Blackberries   Fresh       6.7483
# 11                              Blackberries  Frozen       4.8277
# 12                               Blueberries   Fresh       4.1575
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fruit               62 non-null     object
#  1   Form                62 non-null     object
#  2   RetailPrice         62 non-null     float64
#  3   RetailPriceUnit     62 non-null     object
#  4   Yield               62 non-null     float64
#  5   CupEquivalentSize   62 non-null     float64
#  6   CupEquivalentUnit   62 non-null     object
#  7   CupEquivalentPrice  62 non-null     float64
# dtypes: float64(4), object(4)
# memory usage: 4.0+ KB

# %%
df.shape
# Out:
# (62, 8)

# %%
df.describe().T
# Out:
#                     count      mean       std     min       25%      50%  \
# RetailPrice          62.0  2.994571  2.269393  0.3820  1.364225  2.15925
# Yield                62.0  0.876129  0.174979  0.4600  0.722500  0.98000
# CupEquivalentSize    62.0  1.704984  2.949262  0.1232  0.322450  0.36380
# CupEquivalentPrice   62.0  1.065056  0.578325  0.2429  0.639300  1.00825
#
#                          75%      max
# RetailPrice         4.116525  10.3035
# Yield               1.000000   1.0000
# CupEquivalentSize   0.540100   8.0000
# CupEquivalentPrice  1.353475   3.5558

# %%
df.isnull().sum()*100/len(df)
# Out:
# Fruit                 0.0
# Form                  0.0
# RetailPrice           0.0
# RetailPriceUnit       0.0
# Yield                 0.0
# CupEquivalentSize     0.0
# CupEquivalentUnit     0.0
# CupEquivalentPrice    0.0
# dtype: float64

# %%
df1 = pd.read_csv("/home/moritus-peters/Documents/Analysis-for-a-cost-of-2-cup-recommendation-by-USDA-for-a-household/data/vegetables.csv")

# %%
df
# Out:
#                                        Fruit    Form  RetailPrice  \
# 0                                     Apples   Fresh       1.8541
# 1                         Apples, applesauce  Canned       1.1705
# 2                     Apples, ready-to-drink   Juice       0.8699
# 3                 Apples, frozen concentrate   Juice       0.6086
# 4                                   Apricots   Fresh       3.6162
# 5                  Apricots, packed in juice  Canned       1.8645
# 6         Apricots, packed in syrup or water  Canned       2.2362
# 7                                   Apricots   Dried       7.6611
# 8                                    Bananas   Fresh       0.5971
# 9                             Berries, mixed  Frozen       4.2673
# 10                              Blackberries   Fresh       6.7483
# 11                              Blackberries  Frozen       4.8277
# 12                               Blueberries   Fresh       4.1575
# ...

# %%
df.shape
# Out:
# (62, 8)
